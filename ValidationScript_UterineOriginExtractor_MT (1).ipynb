# %%
# @title Install necessary libraries
# !pip install -q google-genai google-cloud-storage pypdf google-colab
print("Libraries installed.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.5/310.5 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 21.3 MB/s eta 0:00:00
# Libraries installed.

# %%
# @title Import libraries and authenticate
from google import genai
from google.cloud import storage
from google.colab import auth
from google.genai.types import Part, GenerateContentConfig # Import Part for file input
import pypdf
import os
import json
import textwrap # For printing long text nicely
from IPython.display import display, Markdown # For better output formatting

# Authenticate the Colab user for GCP access (like GCS)
print("Authenticating user for Google Cloud access...")
auth.authenticate_user()
print("Authentication successful.")
# Out:
# Authenticating user for Google Cloud access...
# Authentication successful.

# %%
# !gcloud auth list
# Out:
#        Credentialed Accounts
# ACTIVE  ACCOUNT
# *       KalpashreeRajanna@gmail.com
#
# To set the active account, run:
#     $ gcloud config set account `ACCOUNT`

# %%
# !gcloud projects list
# Out:
# PROJECT_ID                 NAME                      PROJECT_NUMBER
# pro-tuner-466721-j1        My First Project          1012279005356
# resounding-keel-466721-r8  My First Project          378047208130
# spatial-racer-466721-k4    My First Project          706052804423
# tensile-talent-466721-p7   paper-extraction-talhouk  928325513656

# %%
# !gcloud projects add-iam-policy-binding paper-extraction-talhouk \
  --member="user:kalpashreerajanna@gmail.com" \
  --role="roles/aiplatform.user"
# Out:
# ERROR: (gcloud.projects.add-iam-policy-binding) [KalpashreeRajanna@gmail.com] does not have permission to access projects instance [paper-extraction-talhouk:getIamPolicy] (or it may not exist): The caller does not have permission. This command is authenticated as KalpashreeRajanna@gmail.com which is the active account specified by the [core/account] property

# %%
# !gcloud projects get-iam-policy paper-extraction-talhouk --format=json > policy.json
# Out:
# ERROR: (gcloud.projects.get-iam-policy) [KalpashreeRajanna@gmail.com] does not have permission to access projects instance [paper-extraction-talhouk:getIamPolicy] (or it may not exist): The caller does not have permission. This command is authenticated as KalpashreeRajanna@gmail.com which is the active account specified by the [core/account] property

# %%
# @title Configure Google Cloud Settings and connect Google Cloud Storage
#    Replace with your actual Project ID, Bucket Name, and Prefix (folder)
GCP_PROJECT_ID = "extraction-papers-talhouk2"
GCS_BUCKET_NAME = "tlab-extractionbucket3"
GCS_PREFIX = "papers3" # e.g., "papers/neuroscience/" or "" for root
LOCATION = "us-central1" # location you want to use for data procssing

# Optional: Set project for GCS client (often inferred after auth, but explicit is safer)
try:
    storage_client = storage.Client(project=GCP_PROJECT_ID)
    print(f"Google Cloud Storage client initialized for project '{GCP_PROJECT_ID}'.")
except Exception as e:
     print(f"Error initializing GCS Client: {e}. Trying without explicit project ID.")
     try:
         storage_client = storage.Client()
         inferred_project = storage_client.project
         print(f"Google Cloud Storage client initialized using inferred project '{inferred_project}'.")
         GCP_PROJECT_ID = inferred_project # Update if inferred
     except Exception as e2:
         print(f"FATAL ERROR: Could not initialize GCS Client: {e2}")
         storage_client = None # Ensure it's None if failed
# Out:
# Google Cloud Storage client initialized for project 'extraction-papers-talhouk2'.

# %%
# # @title Model Selection
MODEL_NAME = "gemini-2.0-flash-001"
client = genai.Client(vertexai=True, project=GCP_PROJECT_ID, location=LOCATION)
print(f"Using Gemini model: {MODEL_NAME}")
# Out:
# Using Gemini model: gemini-2.0-flash-001

# %%
# @title Model Selection - USE THIS ONE
#MODEL_NAME = "gemini-2.0-flash-001"
#client = genai.Client(api_key='AIzaSyDxmQYuRB0g4OuukGqp6Od4cBGUXyum-No')
#print(f"Using Gemini model: {MODEL_NAME}")

# %%
# @title Define Entities To Extract
ENTITIES_TO_EXTRACT = {
  #"Title of Paper": "Extract the title of the paper, e.g., POLE exonuclease domain mutation predicts long progression-free survival in grade 3 endometrioid carcinoma of the endometrium",
    #"Author list": "Extract the full list of authors, e.g., DeRycke M, Andersen J.D., Harrington K.M., Pambuccian S.E., Kalloger S.E., Boylan K.L.M., et al.",
   #  "Histology": "Based on the primary cancer type under study, classify the paper as one of the following: Ovarian (including ovarian cancers with endometrioid histology or arising from endometriosis, such as endometriosis-associated ovarian cancer), Endometrial (only if the primary cancer is located in the endometrium), Both (if both ovarian and endometrial cancers are studied as distinct primary cancers), Neither (if neither is a focus of the study), Do not classify as 'Endometrial' just because of endometrioid histology unless the primary site is explicitly the uterus. Likewise, do not choose 'Both' unless both cancers are discussed as distinct primary diseases.”",

 #   "Histology subtype":"""Extract up to 5 distinct histological cancer subtypes discussed in the study, focusing on the most prominently analyzed or referenced.


# Use the following controlled vocabulary only (do not invent new labels):

# Endometrial Cancer

# Endometrioid Endometrial Cancer

# Non-Endometrioid Endometrial Cancer

# Endometrial Serous Carcinoma

# Endometrial Clear Cell Carcinoma

# Uterine Papillary Serous Carcinoma

# Endometrial Mucinous Carcinoma

# Small Cell Carcinoma of the Endometrium

# Malignant Mixed Mesodermal Tumour (carcinosarcoma)

# Not otherwise specified Endometrial Adenocarcinoma

# Endometrioid Ovarian Carcinoma

# Clear Cell Ovarian Carcinoma

# Endometriosis-associated Ovarian Cancer

# Serous Ovarian Carcinoma

# High-Grade Serous Ovarian Carcinoma

# Important:

# Do not confuse Endometrioid Ovarian Carcinoma with Endometriosis-associated Ovarian Cancer — they are distinct subtypes.

# List only the most frequently or centrally analyzed subtypes.

# If more than 5 are mentioned, return the top 5 and add "Other" at the end.

# Format your answer as a comma-separated list, e.g.:
# Endometrioid Endometrial Cancer, High-Grade Serous Ovarian Carcinoma, Endometrial Serous Carcinoma, Clear Cell Ovarian Carcinoma, Other""",
    #  "Publisher":"Extract the publisher, e.g., Gynecol Oncol",
  # "N of total cohort":"Extract the full sample size of the patient cohort that was analysed in the study. Carefully evaluate if multiple cohorts are mentioned and add them up. Return only one number, e.g., 192",
   # "Date of diagnosis":"Extract the date range of when the patients in the cohort received the first diagnosis, e.g., 2005 - 2011",
     "Primary location of study":"Extract the primary city and country of the study, e.g,. Vancouver, Canada",
    # "Treatments applied in the study": "Extract a detailed summary of all treatments applied to patients in the study. Include initial treatments (e.g., surgery, debulking, salpingo-oophorectomy), chemotherapy (specify neoadjuvant or adjuvant, and agents like platinum-based, taxol, cisplatin), radiation therapy (e.g., external beam, vaginal brachytherapy), hormonal therapy (e.g., megestrol, progesterone IUS), and any targeted or immunotherapies. For each treatment, report the number of patients and percentages if available. State clearly if patients received no treatment. If treatments differ by cancer subtype, report separately. If only general treatment statements are given (e.g., 'all received platinum-based chemotherapy after surgery'), extract those directly. If treatment information is not available, return 'N/A'. Return answers in a structured, itemized format with precise counts and treatment types.",
    # "Analysis":"Extract the technology used to perform the analysis of the primary samples, e.g., IHC TMA",
    # "Analysed Biomarkers":"Extract which biomarkers were analysed in the study, e.g., POLE, p53, MMR, L1CAM, BRCA1. Only extract the top 3 most significant biomarkers, often mentioned in the methods and/or abstract and/or conclusion",
    # "Significant in multivariate (1), univariate (2), or both (3), analysis not significant (4) or unknown (5)":"Determine whether the biomarker or treatment of interest showed statistical significance in univariate analysis, multivariate analysis, both, neither, or if unknown/not reported (codes: 1 = multivariate only, 2 = univariate only, 3 = both, 4 = neither, 5 = unknown), where univariate analysis examines one variable at a time and multivariate analysis adjusts for multiple variables (often described using terms like “Cox regression,” “adjusted for,” or “independent predictor”); if statistical significance is reported without mention of adjustment or multivariate methods, assume univariate analysis.",
    # "Did the identified biomarker or treatment improve prognosis? Prognosis: Improved (1), Worse (2), Both (3), not significant (4), unknown (5)":"Determine the overall effect of the identified biomarker(s) or treatment on patient prognosis and return only one code—1 = improved, 2 = worse, 3 = both (if different subgroups or biomarkers show opposing effects), 4 = no significant effect, 5 = unknown—and if there are mixed effects, return 3 with a brief rationale.",
    # "N histotype":"Extract and explicitly state the histotype composition of the full study cohort. Only report histotypes, such as: Endometrial Carcinoma, Endometrioid Endometrial Carcinoma, Endometrioid Ovarian Carcinoma, Clear Cell Ovarian Carcinoma, Serous Ovarian Carcinoma, etc. Provide exact numbers for each histotype if available. If only percentages are given, calculate and report estimated numbers based on total cohort size. Do not include molecular subtypes, treatment information, or any other clinical characteristics. If no histotype breakdown is provided, return 'N/A'. The output should be limited strictly to histotype cohort composition.",
    # "Was a recent histological review (using 2014 WHO criteria) performed?":"The 2014 WHO criteria specify that the study should provide detailed diagnostic criteria, including histological features, grading and immunohistochemical markers; Or whether there were one or more pathologists who reviewed cases. Determine if this information is available and respond with Yes or No",
    # "5-Year Survival rates (overall survival unless states otherwise)":"Extract the 5-year survival rate, prioritizing overall survival (OS). If OS is not explicitly stated in the main text, check tables, figures, or Kaplan-Meier plots. If only a different survival type is available (e.g., progression-free survival [PFS] or disease-free survival [DFS]), report it and clearly specify the type. Format the result as: 'OVERALL SURVIVAL: 88.3%' or 'PFS: 76.1%'. If no survival data is found anywhere in the paper, return: 'NOT REPORTED'.",
    # "Mean age of participants":"Extract the mean age of participants. If mean is not available, provide the median age. Always specify which is used. Format: MEAN: 42.9, MEDIAN: 45.3. If neither is found, return: AGE NOT REPORTED",
    #  "% of participants with clinicopathological features (Stage I or II)":"Extract the percentage of study participants with disease Stage I or Stage II tumors, e.g., 97%",
    # "REMARK Critera":"Check if the study explicitly states that it followed REMARK criteria. Look for phrases such as:'according to the REMARK criteria','REMARK reporting criteria','in accordance with REMARK guidelines','REMARK recommendations', or any mention of 'REMARK' in reference to study design or analysis. If such a phrase is found, return: 'Yes', If there is no mention of REMARK criteria or guidelines, return: 'No', Do not infer based on formatting or study structure — rely only on explicit textual mention.",
    # "Conclusion of the study":"Extract a brief summary of the conclusion of the study, e.g., ProMisE subgroups are associated with patient outcome in both univariate and multivariate analysis."

}

# %%
# @title Helper Functions
import re

def list_pdfs_in_gcs(client, bucket_name, prefix):
    """Lists PDF files in a GCS bucket/prefix."""
    if not client:
        print("GCS client not initialized. Cannot list files.")
        return []
    print(f"Listing PDFs in gs://{bucket_name}/{prefix}...")
    try:
        bucket = client.get_bucket(bucket_name)
        blobs = client.list_blobs(bucket, prefix=prefix)
        pdf_files = [f"gs://{bucket_name}/{blob.name}" for blob in blobs if blob.name.lower().endswith(".pdf") and blob.size > 0]
        print(f"Found {len(pdf_files)} PDF files.")
        return pdf_files
    except Exception as e:
        print(f"Error listing GCS files: {e}")
        return []

def extract_entities_with_gemini_uri(gcs_uri, entities):
    """Uses Gemini to extract specified entities directly from a PDF URI."""
    if not gcs_uri or not gcs_uri.startswith("gs://"):
        return {"error": "Invalid GCS URI provided"}

    print(f"  Preparing request for Gemini with URI: {gcs_uri}")
    # Create a Part object representing the PDF file in GCS
    try:
        pdf_file = Part.from_uri(
            file_uri=gcs_uri,
            mime_type="application/pdf" # Crucial for the model to know the file type
        )
    except Exception as e:
        print(f"  Error creating Part from URI {gcs_uri}: {e}")
        return {"error": f"Failed to create Part from URI: {e}"}

    system_instruction=(
        """Analyze the provided PDF file (research paper) and extract the entities given to you in your prompt.
        Provide the output strictly in JSON format with the keys from the prompt.
        If an entity cannot be found or is not applicable, use the value "n/a".
        JSON Output:"""
    ),

    # Construct the prompt, instructing the model to analyze the *provided file*
    print(f"  Calling Gemini API for {gcs_uri}...")
    results = {}

    for entity in entities:
        print(f"  Processing entity: {entity}")
        prompt = f"""
        Extract the following entity from the research paper:

        **Entity**: {entity}

        **Instructions**: {entities[entity]}

        Please return the result strictly in the following JSON format:
        {{
          "{entity}": {{
            "value": "The extracted information",
            "confidence": ["confidence score from 0 to 100 as a percentage", a short one sentence rationale for why the confidence score was given]
          }}
        }}

        If the entity is not found, set "value" to "n/a" and "confidence" to 0.
        """

        # Make the API call with both the prompt and the file Part
        try:
            # The request contains both the text prompt and the file reference
            response = client.models.generate_content(
                model=MODEL_NAME,
                config=GenerateContentConfig(
                    system_instruction=system_instruction),
                contents=[prompt, pdf_file],
                )
            print(f"  Received response from Gemini.")

            # Basic check for response content
            if not response.candidates or not response.candidates[0].content.parts:
                print("  Warning: Gemini response seems empty or malformed.")
                # Check for safety ratings or finish reasons if available
                try:
                    finish_reason = response.candidates[0].finish_reason
                    safety_ratings = response.candidates[0].safety_ratings
                    print(f"  Finish Reason: {finish_reason}")
                    print(f"  Safety Ratings: {safety_ratings}")
                    if response.prompt_feedback:
                        print(f"  Prompt Feedback: {response.prompt_feedback}")
                except (AttributeError, IndexError):
                    pass # Ignore if these attributes don't exist
                return {"error": "Empty or malformed response from API", "raw_response": str(response)}

            extracted_text = response.text
            #print(f"Gemini returned {response.text}")

            # Attempt to parse the JSON response
            try:
                # Clean potential markdown formatting around the JSON
                if extracted_text.strip().startswith("```json"):
                    extracted_text = extracted_text.strip()[7:-3].strip()
                elif extracted_text.strip().startswith("```"):
                    extracted_text = extracted_text.strip()[3:-3].strip()

                result = json.loads(extracted_text)
                for entry in result:
                    results[entity] = result[entry]

            except json.JSONDecodeError:
                print(f"  Warning: Failed to parse JSON response from Gemini.")
                # Log the raw response for debugging
                print(f"  Raw response snippet:\n---\n{textwrap.shorten(extracted_text, width=200, placeholder='...')}\n---")
                #return {"error": "Failed to parse JSON response", "raw_response": extracted_text}
            except Exception as e:
                print(f"  Error processing Gemini response content: {e}")
                #return {"error": f"Error processing response content: {e}", "raw_response": extracted_text}

        except Exception as e:
            # Catch potential API errors (e.g., permission denied on GCS URI, rate limits)
            print(f"  ERROR calling Gemini API for {gcs_uri}: {e}")
            # Check if the error message indicates a permission issue
            if "permission denied" in str(e).lower() or "could not access" in str(e).lower():
                print("  This might be a GCS permission issue. See the note in Cell 3 about granting the 'Storage Object Viewer' role.")
                #return {"error": f"Gemini API call failed: {e}"}
      # Validate that all requested keys are present

    validated_result = {}
    for entity in entities:
        validated_result[entity] = results.get(entity, "n/a") # Default to "Not Found" if key is missing
    return validated_result

# %%
# @title ## MEREDITH Extractor

all_results = []
limit = 56

# Check prerequisites
if not client:
    print("ERROR: GenAI Client not initialized. Please fix configuration.")
elif not storage_client:
    print("ERROR: GCS client not initialized. Please fix configuration.")
else:
    # 1. List PDF files in GCS
    pdf_uris = list_pdfs_in_gcs(storage_client, GCS_BUCKET_NAME, GCS_PREFIX)

    if not pdf_uris:
        print("\nNo PDF files found or error listing files. Ensure configuration is correct and files exist.")
    else:
        print(f"\nStarting entity extraction for {len(pdf_uris)} PDF files using URIs...")

        # 2. Loop through each PDF URI
        for i, pdf_uri in enumerate(pdf_uris):
          if i > limit:
            break
          print(f"\n--- Processing file {i+1}/{len(pdf_uris)}: {pdf_uri} ---")
          file_result = {"pdf_uri": pdf_uri}

          # 3. Extract Entities using Gemini directly with the URI
          entities_data = extract_entities_with_gemini_uri(pdf_uri, ENTITIES_TO_EXTRACT)
          file_result.update(entities_data)

          if "error" in entities_data:
              print(f"Extraction failed for {pdf_uri}: {entities_data['error']}")
          else:
                print(f"Extraction successful for {pdf_uri}.")

          all_results.append(file_result)

          # Optional: Add a small delay to avoid hitting potential rate limits
          # time.sleep(1) # Sleep for 1 second between requests

        print("\n--- Processing Complete ---")


print(f"\n--- Extracted Information ({len(all_results)} files processed) ---")

# Check if any results were generated
if not all_results:
    print("No results were generated. Please check previous cell outputs for errors.")
else:
    # Iterate and display results for each file
    for result in all_results:
        display(Markdown(f"**File:** `{result.get('pdf_uri', 'N/A')}`")) # Get URI safely
        if "error" in result:
            # Display error message clearly
            display(Markdown(f"  - **Status:** <font color='red'>Error - {result['error']}</font>"))
            # Optionally display raw response snippet if available and useful
            if "raw_response" in result:
                 display(Markdown(f"  - **Raw Response Snippet:**"))
                 display(Markdown(f"```\n{textwrap.shorten(result['raw_response'], width=150, placeholder='...')}\n```"))
        else:
            # Display success and extracted entities
            display(Markdown(f"  - **Status:** <font color='green'>Success</font>"))
            for entity in ENTITIES_TO_EXTRACT:
                value = result.get(entity, "Not Found") # Use .get for safety
                # Format list display (e.g., for authors)
                if isinstance(value, list):
                     display(Markdown(f"  - **{entity}:** {', '.join(map(str, value)) if value else 'None'}")) # Handle non-string list items
                else:
                     display(Markdown(f"  - **{entity}:** {value}"))
        display(Markdown("---")) # Add a separator between file results
# Out:
# Listing PDFs in gs://tlab-extractionbucket3/papers3...
# Found 50 PDF files.
#
# Starting entity extraction for 50 PDF files using URIs...
#
# --- Processing file 1/50: gs://tlab-extractionbucket3/papers3/S023_Frequent Mismatch Repair Protein Deficiency in Mixed Endometrioid and Clear Cell Carcinoma of the Endometrium.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S023_Frequent Mismatch Repair Protein Deficiency in Mixed Endometrioid and Clear Cell Carcinoma of the Endometrium.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S023_Frequent Mismatch Repair Protein Deficiency in Mixed Endometrioid and Clear Cell Carcinoma of the Endometrium.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S023_Frequent Mismatch Repair Protein Deficiency in Mixed Endometrioid and Clear Cell Carcinoma of the Endometrium.pdf.
#
# --- Processing file 2/50: gs://tlab-extractionbucket3/papers3/S024_Markers of the p53 pathway further refine molecular profiling in high-risk endometrial cancer- A TransPORTEC initiative.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S024_Markers of the p53 pathway further refine molecular profiling in high-risk endometrial cancer- A TransPORTEC initiative.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S024_Markers of the p53 pathway further refine molecular profiling in high-risk endometrial cancer- A TransPORTEC initiative.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S024_Markers of the p53 pathway further refine molecular profiling in high-risk endometrial cancer- A TransPORTEC initiative.pdf.
#
# --- Processing file 3/50: gs://tlab-extractionbucket3/papers3/S025_Endometrial Carcinomas with POLE Exonuclease Domain Mutations Have a Favorable Prognosis.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S025_Endometrial Carcinomas with POLE Exonuclease Domain Mutations Have a Favorable Prognosis.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S025_Endometrial Carcinomas with POLE Exonuclease Domain Mutations Have a Favorable Prognosis.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S025_Endometrial Carcinomas with POLE Exonuclease Domain Mutations Have a Favorable Prognosis.pdf.
#
# --- Processing file 4/50: gs://tlab-extractionbucket3/papers3/S026_Association of p16 expression with prognosis varies across ovarian carcinoma histotypes- an Ovarian Tumor Tissue Analysis consortium study.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S026_Association of p16 expression with prognosis varies across ovarian carcinoma histotypes- an Ovarian Tumor Tissue Analysis consortium study.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S026_Association of p16 expression with prognosis varies across ovarian carcinoma histotypes- an Ovarian Tumor Tissue Analysis consortium study.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S026_Association of p16 expression with prognosis varies across ovarian carcinoma histotypes- an Ovarian Tumor Tissue Analysis consortium study.pdf.
#
# --- Processing file 5/50: gs://tlab-extractionbucket3/papers3/S027_Sex Steroid Hormone Receptor Expression Affects Ovarian Cancer Survival.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S027_Sex Steroid Hormone Receptor Expression Affects Ovarian Cancer Survival.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S027_Sex Steroid Hormone Receptor Expression Affects Ovarian Cancer Survival.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S027_Sex Steroid Hormone Receptor Expression Affects Ovarian Cancer Survival.pdf.
#
# --- Processing file 6/50: gs://tlab-extractionbucket3/papers3/S028_PIK3CA missense mutation is associated with unfavorable outcome in grade 3 endometrioid carcinoma but not in serous endometrial carcinoma.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S028_PIK3CA missense mutation is associated with unfavorable outcome in grade 3 endometrioid carcinoma but not in serous endometrial carcinoma.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S028_PIK3CA missense mutation is associated with unfavorable outcome in grade 3 endometrioid carcinoma but not in serous endometrial carcinoma.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S028_PIK3CA missense mutation is associated with unfavorable outcome in grade 3 endometrioid carcinoma but not in serous endometrial carcinoma.pdf.
#
# --- Processing file 7/50: gs://tlab-extractionbucket3/papers3/S029_MMR deficiency is common in high-grade endometrioid carcinomas and is associated with an unfavorable outcome.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S029_MMR deficiency is common in high-grade endometrioid carcinomas and is associated with an unfavorable outcome.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S029_MMR deficiency is common in high-grade endometrioid carcinomas and is associated with an unfavorable outcome.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S029_MMR deficiency is common in high-grade endometrioid carcinomas and is associated with an unfavorable outcome.pdf.
#
# --- Processing file 8/50: gs://tlab-extractionbucket3/papers3/S30_Integrated genomic characterization of endometrial carcinoma.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S30_Integrated genomic characterization of endometrial carcinoma.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S30_Integrated genomic characterization of endometrial carcinoma.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S30_Integrated genomic characterization of endometrial carcinoma.pdf.
#
# --- Processing file 9/50: gs://tlab-extractionbucket3/papers3/S31_ARID1A mutations in endometriosis-associated ovarian carcinomas.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S31_ARID1A mutations in endometriosis-associated ovarian carcinomas.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S31_ARID1A mutations in endometriosis-associated ovarian carcinomas.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S31_ARID1A mutations in endometriosis-associated ovarian carcinomas.pdf.
#
# --- Processing file 10/50: gs://tlab-extractionbucket3/papers3/S32_Necrosis related HIF-1alpha expression predicts prognosis in patients with endometrioid endometrial carcinoma.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S32_Necrosis related HIF-1alpha expression predicts prognosis in patients with endometrioid endometrial carcinoma.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S32_Necrosis related HIF-1alpha expression predicts prognosis in patients with endometrioid endometrial carcinoma.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S32_Necrosis related HIF-1alpha expression predicts prognosis in patients with endometrioid endometrial carcinoma.pdf.
#
# --- Processing file 11/50: gs://tlab-extractionbucket3/papers3/S33_Low membranous expression of b-catenin and high mitotic count predict poor prognosis in endometrioid carcinoma of the ovary.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S33_Low membranous expression of b-catenin and high mitotic count predict poor prognosis in endometrioid carcinoma of the ovary.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S33_Low membranous expression of b-catenin and high mitotic count predict poor prognosis in endometrioid carcinoma of the ovary.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S33_Low membranous expression of b-catenin and high mitotic count predict poor prognosis in endometrioid carcinoma of the ovary.pdf.
#
# --- Processing file 12/50: gs://tlab-extractionbucket3/papers3/S34_Expression of estrogen receptor-alpha and -beta and progesterone receptor-A and -Bin a large cohort of patients with endometrioid endometrial cancer.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S34_Expression of estrogen receptor-alpha and -beta and progesterone receptor-A and -Bin a large cohort of patients with endometrioid endometrial cancer.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S34_Expression of estrogen receptor-alpha and -beta and progesterone receptor-A and -Bin a large cohort of patients with endometrioid endometrial cancer.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S34_Expression of estrogen receptor-alpha and -beta and progesterone receptor-A and -Bin a large cohort of patients with endometrioid endometrial cancer.pdf.
#
# --- Processing file 13/50: gs://tlab-extractionbucket3/papers3/S35_Cyr61, a member of ccn (connective tissue growth factor cysteine-rich61 nephroblastoma overexpressed) family, predicts survival of patientswith endometrial cancer of endometrioid subtype.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S35_Cyr61, a member of ccn (connective tissue growth factor cysteine-rich61 nephroblastoma overexpressed) family, predicts survival of patientswith endometrial cancer of endometrioid subtype.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S35_Cyr61, a member of ccn (connective tissue growth factor cysteine-rich61 nephroblastoma overexpressed) family, predicts survival of patientswith endometrial cancer of endometrioid subtype.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S35_Cyr61, a member of ccn (connective tissue growth factor cysteine-rich61 nephroblastoma overexpressed) family, predicts survival of patientswith endometrial cancer of endometrioid subtype.pdf.
#
# --- Processing file 14/50: gs://tlab-extractionbucket3/papers3/S36_Promoter methylation of IGFBP-3 and p53 expression in ovarian endometrioid carcinoma.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S36_Promoter methylation of IGFBP-3 and p53 expression in ovarian endometrioid carcinoma.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S36_Promoter methylation of IGFBP-3 and p53 expression in ovarian endometrioid carcinoma.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S36_Promoter methylation of IGFBP-3 and p53 expression in ovarian endometrioid carcinoma.pdf.
#
# --- Processing file 15/50: gs://tlab-extractionbucket3/papers3/S37_Cathepsin B protein levels in endometrial cancer- Potential value as a tumour biomarker.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S37_Cathepsin B protein levels in endometrial cancer- Potential value as a tumour biomarker.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S37_Cathepsin B protein levels in endometrial cancer- Potential value as a tumour biomarker.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S37_Cathepsin B protein levels in endometrial cancer- Potential value as a tumour biomarker.pdf.
#
# --- Processing file 16/50: gs://tlab-extractionbucket3/papers3/S38_Inverse correlation between tumoral indoleamine 2,3-dioxygenase expression and tumor-infiltrating lymphocytes in endometrial cancer- its association with disease progression and survival.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S38_Inverse correlation between tumoral indoleamine 2,3-dioxygenase expression and tumor-infiltrating lymphocytes in endometrial cancer- its association with disease progression and survival.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S38_Inverse correlation between tumoral indoleamine 2,3-dioxygenase expression and tumor-infiltrating lymphocytes in endometrial cancer- its association with disease progression and survival.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S38_Inverse correlation between tumoral indoleamine 2,3-dioxygenase expression and tumor-infiltrating lymphocytes in endometrial cancer- its association with disease progression and survival.pdf.
#
# --- Processing file 17/50: gs://tlab-extractionbucket3/papers3/S39_Expression of class I histone deacetylases indicates poor prognosis in endometrioid subtypes of ovarian and endometrial carcinomas.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S39_Expression of class I histone deacetylases indicates poor prognosis in endometrioid subtypes of ovarian and endometrial carcinomas.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S39_Expression of class I histone deacetylases indicates poor prognosis in endometrioid subtypes of ovarian and endometrial carcinomas.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S39_Expression of class I histone deacetylases indicates poor prognosis in endometrioid subtypes of ovarian and endometrial carcinomas.pdf.
#
# --- Processing file 18/50: gs://tlab-extractionbucket3/papers3/S40_Claudin-3 and claudin-4 expression in serous papillary, clear-cell, and endometrioid endometrial cancer.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S40_Claudin-3 and claudin-4 expression in serous papillary, clear-cell, and endometrioid endometrial cancer.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S40_Claudin-3 and claudin-4 expression in serous papillary, clear-cell, and endometrioid endometrial cancer.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S40_Claudin-3 and claudin-4 expression in serous papillary, clear-cell, and endometrioid endometrial cancer.pdf.
#
# --- Processing file 19/50: gs://tlab-extractionbucket3/papers3/S41_GATA3 expression in estrogen receptor alpha-negative endometrial carcinomas identifies aggressive tumors with high proliferation and poor patient survival.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S41_GATA3 expression in estrogen receptor alpha-negative endometrial carcinomas identifies aggressive tumors with high proliferation and poor patient survival.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S41_GATA3 expression in estrogen receptor alpha-negative endometrial carcinomas identifies aggressive tumors with high proliferation and poor patient survival.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S41_GATA3 expression in estrogen receptor alpha-negative endometrial carcinomas identifies aggressive tumors with high proliferation and poor patient survival.pdf.
#
# --- Processing file 20/50: gs://tlab-extractionbucket3/papers3/S42_Expression of epithelial membrane protein-2 is associated with endometrial adenocarcinoma of unfavorable outcome.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S42_Expression of epithelial membrane protein-2 is associated with endometrial adenocarcinoma of unfavorable outcome.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S42_Expression of epithelial membrane protein-2 is associated with endometrial adenocarcinoma of unfavorable outcome.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S42_Expression of epithelial membrane protein-2 is associated with endometrial adenocarcinoma of unfavorable outcome.pdf.
#
# --- Processing file 21/50: gs://tlab-extractionbucket3/papers3/S43_Progesterone receptor isoforms as a prognostic marker in human endometrial carcinoma.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S43_Progesterone receptor isoforms as a prognostic marker in human endometrial carcinoma.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S43_Progesterone receptor isoforms as a prognostic marker in human endometrial carcinoma.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S43_Progesterone receptor isoforms as a prognostic marker in human endometrial carcinoma.pdf.
#
# --- Processing file 22/50: gs://tlab-extractionbucket3/papers3/S44_Clinical and pathological associations of PTEN expression in ovarian cancer- a multicentre study from the Ovarian Tumour Tissue Analysis Consortium.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S44_Clinical and pathological associations of PTEN expression in ovarian cancer- a multicentre study from the Ovarian Tumour Tissue Analysis Consortium.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S44_Clinical and pathological associations of PTEN expression in ovarian cancer- a multicentre study from the Ovarian Tumour Tissue Analysis Consortium.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S44_Clinical and pathological associations of PTEN expression in ovarian cancer- a multicentre study from the Ovarian Tumour Tissue Analysis Consortium.pdf.
#
# --- Processing file 23/50: gs://tlab-extractionbucket3/papers3/S45_p53 mutations and overexpression affect prognosis of ovarian endometrioid cancer but not clear cell cancer.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S45_p53 mutations and overexpression affect prognosis of ovarian endometrioid cancer but not clear cell cancer.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S45_p53 mutations and overexpression affect prognosis of ovarian endometrioid cancer but not clear cell cancer.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S45_p53 mutations and overexpression affect prognosis of ovarian endometrioid cancer but not clear cell cancer.pdf.
#
# --- Processing file 24/50: gs://tlab-extractionbucket3/papers3/S46_Characterization of ovarian clear cell carcinoma using target drug-based molecular biomarkers- implications for personalized cancer therapy.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S46_Characterization of ovarian clear cell carcinoma using target drug-based molecular biomarkers- implications for personalized cancer therapy.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S46_Characterization of ovarian clear cell carcinoma using target drug-based molecular biomarkers- implications for personalized cancer therapy.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S46_Characterization of ovarian clear cell carcinoma using target drug-based molecular biomarkers- implications for personalized cancer therapy.pdf.
#
# --- Processing file 25/50: gs://tlab-extractionbucket3/papers3/S47_CD103 defines intraepithelial CD8+ PD1+ tumour-infiltrating lymphocytes of prognostic significance in endometrial adenocarcinoma.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S47_CD103 defines intraepithelial CD8+ PD1+ tumour-infiltrating lymphocytes of prognostic significance in endometrial adenocarcinoma.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S47_CD103 defines intraepithelial CD8+ PD1+ tumour-infiltrating lymphocytes of prognostic significance in endometrial adenocarcinoma.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S47_CD103 defines intraepithelial CD8+ PD1+ tumour-infiltrating lymphocytes of prognostic significance in endometrial adenocarcinoma.pdf.
#
# --- Processing file 26/50: gs://tlab-extractionbucket3/papers3/S48_Prognostic significance of L1CAM expression and its association with mutant p53 expression in high-risk endometrial cancer.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S48_Prognostic significance of L1CAM expression and its association with mutant p53 expression in high-risk endometrial cancer.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S48_Prognostic significance of L1CAM expression and its association with mutant p53 expression in high-risk endometrial cancer.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S48_Prognostic significance of L1CAM expression and its association with mutant p53 expression in high-risk endometrial cancer.pdf.
#
# --- Processing file 27/50: gs://tlab-extractionbucket3/papers3/S49_L1CAM Expression is Related to Non-Endometrioid Histology, and Prognostic for Poor Outcome in Endometrioid Endometrial Carcinoma..pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S49_L1CAM Expression is Related to Non-Endometrioid Histology, and Prognostic for Poor Outcome in Endometrioid Endometrial Carcinoma..pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S49_L1CAM Expression is Related to Non-Endometrioid Histology, and Prognostic for Poor Outcome in Endometrioid Endometrial Carcinoma..pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S49_L1CAM Expression is Related to Non-Endometrioid Histology, and Prognostic for Poor Outcome in Endometrioid Endometrial Carcinoma..pdf.
#
# --- Processing file 28/50: gs://tlab-extractionbucket3/papers3/S50_Silencing of UCA1, a poor prognostic factor, inhibited the migration of endometrial cancer cell.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S50_Silencing of UCA1, a poor prognostic factor, inhibited the migration of endometrial cancer cell.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S50_Silencing of UCA1, a poor prognostic factor, inhibited the migration of endometrial cancer cell.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S50_Silencing of UCA1, a poor prognostic factor, inhibited the migration of endometrial cancer cell.pdf.
#
# --- Processing file 29/50: gs://tlab-extractionbucket3/papers3/S51_DNA mismatch repair-related protein loss as a prognostic factor in endometrial cancers.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S51_DNA mismatch repair-related protein loss as a prognostic factor in endometrial cancers.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S51_DNA mismatch repair-related protein loss as a prognostic factor in endometrial cancers.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S51_DNA mismatch repair-related protein loss as a prognostic factor in endometrial cancers.pdf.
#
# --- Processing file 30/50: gs://tlab-extractionbucket3/papers3/S52_Expression and clinical significance of annexin A2 and human epididymis protein 4 in endometrial carcinoma (1).pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S52_Expression and clinical significance of annexin A2 and human epididymis protein 4 in endometrial carcinoma (1).pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S52_Expression and clinical significance of annexin A2 and human epididymis protein 4 in endometrial carcinoma (1).pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S52_Expression and clinical significance of annexin A2 and human epididymis protein 4 in endometrial carcinoma (1).pdf.
#
# --- Processing file 31/50: gs://tlab-extractionbucket3/papers3/S53_ARID1A loss correlates with mismatch repair deficiency and intact p53 expression in high-grade endometrial carcinomas.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S53_ARID1A loss correlates with mismatch repair deficiency and intact p53 expression in high-grade endometrial carcinomas.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S53_ARID1A loss correlates with mismatch repair deficiency and intact p53 expression in high-grade endometrial carcinomas.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S53_ARID1A loss correlates with mismatch repair deficiency and intact p53 expression in high-grade endometrial carcinomas.pdf.
#
# --- Processing file 32/50: gs://tlab-extractionbucket3/papers3/S54_L1 cell adhesion molecule is a strong predictor for distant recurrence and overall survival in early stage endometrial cancer- pooled PORTEC trial results.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S54_L1 cell adhesion molecule is a strong predictor for distant recurrence and overall survival in early stage endometrial cancer- pooled PORTEC trial results.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S54_L1 cell adhesion molecule is a strong predictor for distant recurrence and overall survival in early stage endometrial cancer- pooled PORTEC trial results.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S54_L1 cell adhesion molecule is a strong predictor for distant recurrence and overall survival in early stage endometrial cancer- pooled PORTEC trial results.pdf.
#
# --- Processing file 33/50: gs://tlab-extractionbucket3/papers3/S55_Evidence for a time-dependent association between FOLR1 expression and survival from ovarian carcinoma- implications for clinical testing. An Ovarian Tumour Tissue Analysis consortium study..pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S55_Evidence for a time-dependent association between FOLR1 expression and survival from ovarian carcinoma- implications for clinical testing. An Ovarian Tumour Tissue Analysis consortium study..pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S55_Evidence for a time-dependent association between FOLR1 expression and survival from ovarian carcinoma- implications for clinical testing. An Ovarian Tumour Tissue Analysis consortium study..pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S55_Evidence for a time-dependent association between FOLR1 expression and survival from ovarian carcinoma- implications for clinical testing. An Ovarian Tumour Tissue Analysis consortium study..pdf.
#
# --- Processing file 34/50: gs://tlab-extractionbucket3/papers3/S56_PIK3CA overexpression is a possible prognostic factor for favorable survival in ovarian clear cell carcinoma.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S56_PIK3CA overexpression is a possible prognostic factor for favorable survival in ovarian clear cell carcinoma.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S56_PIK3CA overexpression is a possible prognostic factor for favorable survival in ovarian clear cell carcinoma.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S56_PIK3CA overexpression is a possible prognostic factor for favorable survival in ovarian clear cell carcinoma.pdf.
#
# --- Processing file 35/50: gs://tlab-extractionbucket3/papers3/S57_Immunoexpression of B7-H3 in endometrial cancer- relation to tumor T-cell infiltration and prognosis.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S57_Immunoexpression of B7-H3 in endometrial cancer- relation to tumor T-cell infiltration and prognosis.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S57_Immunoexpression of B7-H3 in endometrial cancer- relation to tumor T-cell infiltration and prognosis.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S57_Immunoexpression of B7-H3 in endometrial cancer- relation to tumor T-cell infiltration and prognosis.pdf.
#
# --- Processing file 36/50: gs://tlab-extractionbucket3/papers3/S58_The autophagy protein LC3A correlates with hypoxia and is a prognostic marker of patient survival in clear cell ovarian cancer..pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S58_The autophagy protein LC3A correlates with hypoxia and is a prognostic marker of patient survival in clear cell ovarian cancer..pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S58_The autophagy protein LC3A correlates with hypoxia and is a prognostic marker of patient survival in clear cell ovarian cancer..pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S58_The autophagy protein LC3A correlates with hypoxia and is a prognostic marker of patient survival in clear cell ovarian cancer..pdf.
#
# --- Processing file 37/50: gs://tlab-extractionbucket3/papers3/S59_Stathmin overexpression identifies high-risk patients and lymph node metastasis in endometrial cancer.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S59_Stathmin overexpression identifies high-risk patients and lymph node metastasis in endometrial cancer.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S59_Stathmin overexpression identifies high-risk patients and lymph node metastasis in endometrial cancer.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S59_Stathmin overexpression identifies high-risk patients and lymph node metastasis in endometrial cancer.pdf.
#
# --- Processing file 38/50: gs://tlab-extractionbucket3/papers3/S60_IGF2BP3 (IMP3) expression is a marker of unfavorable prognosis in ovarian carcinoma of clear cell subtype.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S60_IGF2BP3 (IMP3) expression is a marker of unfavorable prognosis in ovarian carcinoma of clear cell subtype.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S60_IGF2BP3 (IMP3) expression is a marker of unfavorable prognosis in ovarian carcinoma of clear cell subtype.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S60_IGF2BP3 (IMP3) expression is a marker of unfavorable prognosis in ovarian carcinoma of clear cell subtype.pdf.
#
# --- Processing file 39/50: gs://tlab-extractionbucket3/papers3/S61_EphA2 overexpression is associated with lack of hormone receptor expression and poor outcome in endometrial cancer.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S61_EphA2 overexpression is associated with lack of hormone receptor expression and poor outcome in endometrial cancer.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S61_EphA2 overexpression is associated with lack of hormone receptor expression and poor outcome in endometrial cancer.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S61_EphA2 overexpression is associated with lack of hormone receptor expression and poor outcome in endometrial cancer.pdf.
#
# --- Processing file 40/50: gs://tlab-extractionbucket3/papers3/S62_Aromatase, cyclooxygenase 2, HER-2 neu, and p53 as prognostic factors in endometrioid endometrial cancer.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S62_Aromatase, cyclooxygenase 2, HER-2 neu, and p53 as prognostic factors in endometrioid endometrial cancer.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S62_Aromatase, cyclooxygenase 2, HER-2 neu, and p53 as prognostic factors in endometrioid endometrial cancer.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S62_Aromatase, cyclooxygenase 2, HER-2 neu, and p53 as prognostic factors in endometrioid endometrial cancer.pdf.
#
# --- Processing file 41/50: gs://tlab-extractionbucket3/papers3/S63_Expression of matriptase and clinical outcome of human endometrial cancer.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S63_Expression of matriptase and clinical outcome of human endometrial cancer.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S63_Expression of matriptase and clinical outcome of human endometrial cancer.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S63_Expression of matriptase and clinical outcome of human endometrial cancer.pdf.
#
# --- Processing file 42/50: gs://tlab-extractionbucket3/papers3/S64_Ovarian carcinoma subtypes are different diseases- implications for biomarker studies.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S64_Ovarian carcinoma subtypes are different diseases- implications for biomarker studies.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S64_Ovarian carcinoma subtypes are different diseases- implications for biomarker studies.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S64_Ovarian carcinoma subtypes are different diseases- implications for biomarker studies.pdf.
#
# --- Processing file 43/50: gs://tlab-extractionbucket3/papers3/S65_Prostate-specific membrane antigen expression is a potential prognostic marker in endometrial adenocarcinoma.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S65_Prostate-specific membrane antigen expression is a potential prognostic marker in endometrial adenocarcinoma.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S65_Prostate-specific membrane antigen expression is a potential prognostic marker in endometrial adenocarcinoma.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S65_Prostate-specific membrane antigen expression is a potential prognostic marker in endometrial adenocarcinoma.pdf.
#
# --- Processing file 44/50: gs://tlab-extractionbucket3/papers3/S66_GPR30- a novel indicator of poor survival for endometrial carcinoma.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S66_GPR30- a novel indicator of poor survival for endometrial carcinoma.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S66_GPR30- a novel indicator of poor survival for endometrial carcinoma.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S66_GPR30- a novel indicator of poor survival for endometrial carcinoma.pdf.
#
# --- Processing file 45/50: gs://tlab-extractionbucket3/papers3/S67_Activation of ERK1-2 occurs independently of KRAS or BRAF status in endometrial cancer and is associated with favorable prognosis.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S67_Activation of ERK1-2 occurs independently of KRAS or BRAF status in endometrial cancer and is associated with favorable prognosis.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S67_Activation of ERK1-2 occurs independently of KRAS or BRAF status in endometrial cancer and is associated with favorable prognosis.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S67_Activation of ERK1-2 occurs independently of KRAS or BRAF status in endometrial cancer and is associated with favorable prognosis.pdf.
#
# --- Processing file 46/50: gs://tlab-extractionbucket3/papers3/S68_HER-2 is an independent prognostic factor in endometrial cancer- association with outcome in a large cohort of surgically staged patients.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S68_HER-2 is an independent prognostic factor in endometrial cancer- association with outcome in a large cohort of surgically staged patients.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S68_HER-2 is an independent prognostic factor in endometrial cancer- association with outcome in a large cohort of surgically staged patients.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S68_HER-2 is an independent prognostic factor in endometrial cancer- association with outcome in a large cohort of surgically staged patients.pdf.
#
# --- Processing file 47/50: gs://tlab-extractionbucket3/papers3/S69_Ezrin expression is related to poor prognosis in FIGO stage I endometrioid carcinomas.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S69_Ezrin expression is related to poor prognosis in FIGO stage I endometrioid carcinomas.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S69_Ezrin expression is related to poor prognosis in FIGO stage I endometrioid carcinomas.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S69_Ezrin expression is related to poor prognosis in FIGO stage I endometrioid carcinomas.pdf.
#
# --- Processing file 48/50: gs://tlab-extractionbucket3/papers3/S70_Replicative MCM7 protein as a proliferation marker in endometrial carcinoma- a tissue microarray and clinicopathological analysis.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S70_Replicative MCM7 protein as a proliferation marker in endometrial carcinoma- a tissue microarray and clinicopathological analysis.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S70_Replicative MCM7 protein as a proliferation marker in endometrial carcinoma- a tissue microarray and clinicopathological analysis.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S70_Replicative MCM7 protein as a proliferation marker in endometrial carcinoma- a tissue microarray and clinicopathological analysis.pdf.
#
# --- Processing file 49/50: gs://tlab-extractionbucket3/papers3/S71_Intratumoral CD8+ T lymphocytes as a prognostic factor of survival in endometrial carcinoma.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S71_Intratumoral CD8+ T lymphocytes as a prognostic factor of survival in endometrial carcinoma.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S71_Intratumoral CD8+ T lymphocytes as a prognostic factor of survival in endometrial carcinoma.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S71_Intratumoral CD8+ T lymphocytes as a prognostic factor of survival in endometrial carcinoma.pdf.
#
# --- Processing file 50/50: gs://tlab-extractionbucket3/papers3/S72_L1 expression as a predictor of progression and survival in patients with uterine and ovarian carcinomas.pdf ---
#   Preparing request for Gemini with URI: gs://tlab-extractionbucket3/papers3/S72_L1 expression as a predictor of progression and survival in patients with uterine and ovarian carcinomas.pdf
#   Calling Gemini API for gs://tlab-extractionbucket3/papers3/S72_L1 expression as a predictor of progression and survival in patients with uterine and ovarian carcinomas.pdf...
#   Processing entity: Primary location of study
#   Received response from Gemini.
# Extraction successful for gs://tlab-extractionbucket3/papers3/S72_L1 expression as a predictor of progression and survival in patients with uterine and ovarian carcinomas.pdf.
#
# --- Processing Complete ---
#
# --- Extracted Information (50 files processed) ---
# **File:** `gs://tlab-extractionbucket3/papers3/S023_Frequent Mismatch Repair Protein Deficiency in Mixed Endometrioid and Clear Cell Carcinoma of the Endometrium.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Calgary, Canada', 'confidence': ['90', 'The paper includes authors affiliated with an institution in Calgary, Canada. This is an educated guess based on author affiliations.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S024_Markers of the p53 pathway further refine molecular profiling in high-risk endometrial cancer- A TransPORTEC initiative.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Manchester, UK', 'confidence': ['90', "The study was conducted at St Mary's Hospital, Manchester, UK and the affiliated University of Manchester and the affiliation is clearly stated in the paper."]}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S025_Endometrial Carcinomas with POLE Exonuclease Domain Mutations Have a Favorable Prognosis.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Vancouver, Canada', 'confidence': ['95', 'The study mentions Vancouver General Hospital, University of British Columbia, and BC Cancer Agency, Vancouver, British Columbia, Canada as affiliations of the authors.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S026_Association of p16 expression with prognosis varies across ovarian carcinoma histotypes- an Ovarian Tumor Tissue Analysis consortium study.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'n/a', 'confidence': ['0', 'The location of the study cannot be determined from the text provided.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S027_Sex Steroid Hormone Receptor Expression Affects Ovarian Cancer Survival.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Lund, Sweden', 'confidence': ['95', 'The abstract and author affiliations clearly state that the study was conducted in Lund, Sweden.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S028_PIK3CA missense mutation is associated with unfavorable outcome in grade 3 endometrioid carcinoma but not in serous endometrial carcinoma.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Calgary, AB, Canada', 'confidence': ['100', 'The study explicitly mentions that patients were diagnosed and treated at the Tom Baker Cancer Centre in Calgary, AB, Canada.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S029_MMR deficiency is common in high-grade endometrioid carcinomas and is associated with an unfavorable outcome.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Calgary, Alberta, Canada', 'confidence': ['100', 'The study mentions that the slides and blocks were archived in Calgary Laboratory Services and clinical data was obtained from Tom Baker Cancer Centre in Calgary.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S30_Integrated genomic characterization of endometrial carcinoma.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Vancouver, Canada', 'confidence': ['85', "The last names of several authors and their institute are listed as coming from  Canada's Michael Smith Genome Sciences Centre, BC Cancer Agency, Vancouver, British Columbia"]}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S31_ARID1A mutations in endometriosis-associated ovarian carcinomas.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Vancouver, Canada', 'confidence': ['95', 'The study explicitly mentions that multiple authors and research centers involved are all located in Vancouver, Canada.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S32_Necrosis related HIF-1alpha expression predicts prognosis in patients with endometrioid endometrial carcinoma.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Utrecht, The Netherlands', 'confidence': ['100', 'The study group was diagnosed between 1992 and 2005 at the University Medical Centre Utrecht, The Netherlands.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S33_Low membranous expression of b-catenin and high mitotic count predict poor prognosis in endometrioid carcinoma of the ovary.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Houston, USA', 'confidence': ['90', 'The text explicitly states that the study was conducted at Baylor College of Medicine and The University of Texas M. D. Anderson Cancer Center, both of which are located in Houston, Texas, USA.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S34_Expression of estrogen receptor-alpha and -beta and progesterone receptor-A and -Bin a large cohort of patients with endometrioid endometrial cancer.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Groningen, The Netherlands', 'confidence': ['100', 'The study explicitly states that all patients were treated at the University Medical Center of Groningen, The Netherlands.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S35_Cyr61, a member of ccn (connective tissue growth factor cysteine-rich61 nephroblastoma overexpressed) family, predicts survival of patientswith endometrial cancer of endometrioid subtype.pdf`
# ...
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Nagoya, Japan', 'confidence': ['100', 'The affiliation of the authors indicates the location of the study is Nagoya University Graduate School of Medicine, Nagoya, Japan.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S39_Expression of class I histone deacetylases indicates poor prognosis in endometrioid subtypes of ovarian and endometrial carcinomas.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Vancouver, Canada', 'confidence': ['100', 'The study was conducted at the Vancouver General Hospital and the British Columbia Cancer Agency, both of which are located in Vancouver, Canada.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S40_Claudin-3 and claudin-4 expression in serous papillary, clear-cell, and endometrioid endometrial cancer.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Rochester, USA', 'confidence': ['100', 'The study was conducted at the Mayo Clinic in Rochester, Minnesota, and University of California Los Angeles, California, USA and National Institute on Aging, NIH, Baltimore, Maryland']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S41_GATA3 expression in estrogen receptor alpha-negative endometrial carcinomas identifies aggressive tumors with high proliferation and poor patient survival.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Bergen, Norway', 'confidence': ['95', "The study explicitly mentions 'University of Bergen, Bergen, Norway' as the location where the research was conducted."]}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S42_Expression of epithelial membrane protein-2 is associated with endometrial adenocarcinoma of unfavorable outcome.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Los Angeles, California', 'confidence': ['100', "The Department of Pathology and Laboratory Medicine, David Geffen School of Medicine at the University of California-Los Angeles, is mentioned as the first author's affiliation."]}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S43_Progesterone receptor isoforms as a prognostic marker in human endometrial carcinoma.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Sendai, Japan', 'confidence': ['100', 'The department of Obstetrics and Gynecology and Pathology, Tohoku University Graduate School of Medicine is located in Sendai, Japan.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S44_Clinical and pathological associations of PTEN expression in ovarian cancer- a multicentre study from the Ovarian Tumour Tissue Analysis Consortium.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Cambridge, UK', 'confidence': ['90', 'The IHC analysis was carried out in Cambridge (UK) using tissue microarrays (TMAs) obtained from formalin-fixed, paraffin-embedded tissues.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S45_p53 mutations and overexpression affect prognosis of ovarian endometrioid cancer but not clear cell cancer.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Tokyo, Japan', 'confidence': ['100', 'The affiliation of the first author, Tsuyoshi Okuda, indicates the study was conducted primarily in Tokyo, Japan.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S46_Characterization of ovarian clear cell carcinoma using target drug-based molecular biomarkers- implications for personalized cancer therapy.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Shanghai, China', 'confidence': ['90', 'The study was conducted at Fudan University Shanghai Cancer Center, which is in Shanghai, China.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S47_CD103 defines intraepithelial CD8+ PD1+ tumour-infiltrating lymphocytes of prognostic significance in endometrial adenocarcinoma.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Groningen, The Netherlands', 'confidence': ['95', 'The authors are affiliated with the University of Groningen, University Medical Center Groningen, in the Netherlands.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S48_Prognostic significance of L1CAM expression and its association with mutant p53 expression in high-risk endometrial cancer.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Leiden, The Netherlands', 'confidence': ['100', 'The correspondence section on page 1 states that the correspondence author is from Leiden University Medical Center, Leiden, The Netherlands.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S49_L1CAM Expression is Related to Non-Endometrioid Histology, and Prognostic for Poor Outcome in Endometrioid Endometrial Carcinoma..pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Nijmegen, The Netherlands', 'confidence': ['90', 'Radboud University Medical Centre Nijmegen is mentioned multiple times, indicating it is the location of the study.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S50_Silencing of UCA1, a poor prognostic factor, inhibited the migration of endometrial cancer cell.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Guangzhou, China', 'confidence': ['100', 'The study was conducted in multiple hospitals in Guangzhou, Guangdong, China as described in the affiliations of the authors.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S51_DNA mismatch repair-related protein loss as a prognostic factor in endometrial cancers.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Tokorozawa, Japan', 'confidence': ['100', 'The study was conducted at the National Defense Medical College Hospital in Tokorozawa, Japan, as stated in the affiliation of the authors.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S52_Expression and clinical significance of annexin A2 and human epididymis protein 4 in endometrial carcinoma (1).pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Shenyang, China', 'confidence': ['95', 'The article mentions that the Shengjing Hospital is affiliated to China Medical University, which is located in Shenyang, Liaoning, China.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S53_ARID1A loss correlates with mismatch repair deficiency and intact p53 expression in high-grade endometrial carcinomas.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Toronto and Vancouver, Canada', 'confidence': ['100', 'The author affiliations clearly mentions that the study has been conducted in these cities.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S54_L1 cell adhesion molecule is a strong predictor for distant recurrence and overall survival in early stage endometrial cancer- pooled PORTEC trial results.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Leiden, The Netherlands', 'confidence': ['95', "Leiden, The Netherlands is mentioned as the location of the Department of Pathology, Leiden University Medical Center, which is the first author's affiliation and therefore is the location of the study."]}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S55_Evidence for a time-dependent association between FOLR1 expression and survival from ovarian carcinoma- implications for clinical testing. An Ovarian Tumour Tissue Analysis consortium study..pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Calgary, Canada', 'confidence': ['90', "The first author's affiliation is listed as being in Calgary, Canada, suggesting this is a primary location for at least part of the study."]}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S56_PIK3CA overexpression is a possible prognostic factor for favorable survival in ovarian clear cell carcinoma.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Tsukuba, Japan', 'confidence': ['95', 'The study was conducted at the University of Tsukuba, located in Tsukuba, Ibaraki, Japan, as stated in the paper.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S57_Immunoexpression of B7-H3 in endometrial cancer- relation to tumor T-cell infiltration and prognosis.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Moedling/Vienna, Austria', 'confidence': ['100', 'The abstract and article information section explicitly state the research was done at Landesklinikum Thermenregion Moedling/Vienna, Austria.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S58_The autophagy protein LC3A correlates with hypoxia and is a prognostic marker of patient survival in clear cell ovarian cancer..pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'British Columbia, Canada', 'confidence': ['100', 'The study mentions the Cheryl Brown Ovarian Cancer Outcomes Unit in the province of British Columbia.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S59_Stathmin overexpression identifies high-risk patients and lymph node metastasis in endometrial cancer.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Bergen, Norway', 'confidence': ['80', 'The study was conducted in 10 centres, but the first one mentioned and where the hysterectomy samples were collected from is Haukeland University Hospital, Bergen, Norway.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S60_IGF2BP3 (IMP3) expression is a marker of unfavorable prognosis in ovarian carcinoma of clear cell subtype.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Vancouver, Canada', 'confidence': ['100', 'The paper explicitly states that the Department of Pathology is in Vancouver, BC, Canada.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S61_EphA2 overexpression is associated with lack of hormone receptor expression and poor outcome in endometrial cancer.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Houston, Texas', 'confidence': ['100', 'The article states that the Department of Gynecologic Oncology, University of Texas M. D. Anderson Cancer Center is in Houston, Texas.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S62_Aromatase, cyclooxygenase 2, HER-2 neu, and p53 as prognostic factors in endometrioid endometrial cancer.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Groningen, The Netherlands', 'confidence': ['100', 'The article explicitly mentions that all patients were treated at the Department of Obstetrics and Gynecology of the University Medical Center of Groningen, The Netherlands']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S63_Expression of matriptase and clinical outcome of human endometrial cancer.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Okayama, Japan', 'confidence': ['100', 'The abstract and affiliations clearly state that the study was conducted at Okayama University Graduate School in Okayama, Japan.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S64_Ovarian carcinoma subtypes are different diseases- implications for biomarker studies.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Vancouver, British Columbia, Canada', 'confidence': ['100', 'The research paper clearly indicates that the Genetic Pathology Evaluation Centre, Department of Pathology, Vancouver General Hospital and British Columbia Cancer Agency, is located in Vancouver, British Columbia, Canada.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S65_Prostate-specific membrane antigen expression is a potential prognostic marker in endometrial adenocarcinoma.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Buffalo, New York', 'confidence': ['95', 'The abstract clearly states that the tissue specimens were obtained from patients undergoing surgery for EAC at Roswell Park Cancer Institute, located in Buffalo, New York.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S66_GPR30- a novel indicator of poor survival for endometrial carcinoma.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Albuquerque, NM, USA', 'confidence': ['95', 'The text specifically mentions that the study was performed at the University of New Mexico Health Sciences Center in Albuquerque, NM.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S67_Activation of ERK1-2 occurs independently of KRAS or BRAF status in endometrial cancer and is associated with favorable prognosis.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Kanazawa, Japan', 'confidence': ['90', 'The research paper explicitly states that the study was conducted at Kanazawa University Hospital in Japan.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S68_HER-2 is an independent prognostic factor in endometrial cancer- association with outcome in a large cohort of surgically staged patients.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Columbus, OH', 'confidence': ['100', 'The study was conducted at the Arthur James Cancer Hospital of the Ohio State University Medical School (OSU; Columbus, OH).']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S69_Ezrin expression is related to poor prognosis in FIGO stage I endometrioid carcinomas.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Halle, Germany', 'confidence': ['100', 'The paper clearly states that the study was conducted at the Institute of Pathology, Martin-Luther-University Halle-Wittenberg, Halle, Germany.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S70_Replicative MCM7 protein as a proliferation marker in endometrial carcinoma- a tissue microarray and clinicopathological analysis.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Hong Kong, China', 'confidence': ['100', 'The study explicitly mentions that the cases were managed in Queen Mary Hospital, University of Hong Kong, indicating the primary location.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S71_Intratumoral CD8+ T lymphocytes as a prognostic factor of survival in endometrial carcinoma.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Haifa, Israel', 'confidence': ['100', 'The research was conducted at Carmel Medical Center and the Technion Rappoport Faculty of Medicine, both located in Haifa, Israel.']}
# ---
# **File:** `gs://tlab-extractionbucket3/papers3/S72_L1 expression as a predictor of progression and survival in patients with uterine and ovarian carcinomas.pdf`
#   - **Status:** <font color='green'>Success</font>
#   - **Primary location of study:** {'value': 'Rehovot, Israel', 'confidence': ['95', 'The study explicitly mentions Kaplan Hospital, Rehovot, Israel as a location for the Departments of Pathology and Gynecology.']}
# ---

# %%
import csv
import pandas as pd

# Replace this with your actual list of dictionaries containing extracted data
# For example: extracted_data = [{'Title of Paper': '...', 'Author list': '...', ...}, ...]
extracted_data = all_results
csv_file_path = 'extracted_results.csv'

# Get all unique fieldnames from your data
fieldnames = list({key for d in extracted_data for key in d.keys()})

with open(csv_file_path, mode='w', newline='', encoding='utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for row in extracted_data:
        writer.writerow(row)

print(f"\nExported extracted results to {csv_file_path}")
# Out:
# Exported extracted results to extracted_results.csv

# %%
#S1 data visualization
import pandas as pd

# Convert data to DataFrame and save to CSV
df = pd.DataFrame(extracted_data)
df.to_csv('extracted_results.csv', index=False)

# Set row numbers (index) to start at 1
df.index = range(1, len(df) + 1)

# Display all rows
pd.set_option('display.max_rows', None)
df
# Out:
#                                               pdf_uri  \
# 1   gs://tlab-extractionbucket3/papers3/S023_Frequ...
# 2   gs://tlab-extractionbucket3/papers3/S024_Marke...
# 3   gs://tlab-extractionbucket3/papers3/S025_Endom...
# 4   gs://tlab-extractionbucket3/papers3/S026_Assoc...
# 5   gs://tlab-extractionbucket3/papers3/S027_Sex S...
# 6   gs://tlab-extractionbucket3/papers3/S028_PIK3C...
# 7   gs://tlab-extractionbucket3/papers3/S029_MMR d...
# 8   gs://tlab-extractionbucket3/papers3/S30_Integr...
# 9   gs://tlab-extractionbucket3/papers3/S31_ARID1A...
# 10  gs://tlab-extractionbucket3/papers3/S32_Necros...
# 11  gs://tlab-extractionbucket3/papers3/S33_Low me...
# 12  gs://tlab-extractionbucket3/papers3/S34_Expres...
# 13  gs://tlab-extractionbucket3/papers3/S35_Cyr61,...
# 14  gs://tlab-extractionbucket3/papers3/S36_Promot...
# 15  gs://tlab-extractionbucket3/papers3/S37_Cathep...
# 16  gs://tlab-extractionbucket3/papers3/S38_Invers...
# 17  gs://tlab-extractionbucket3/papers3/S39_Expres...
# 18  gs://tlab-extractionbucket3/papers3/S40_Claudi...
# 19  gs://tlab-extractionbucket3/papers3/S41_GATA3 ...
# 20  gs://tlab-extractionbucket3/papers3/S42_Expres...
# 21  gs://tlab-extractionbucket3/papers3/S43_Proges...
# 22  gs://tlab-extractionbucket3/papers3/S44_Clinic...
# 23  gs://tlab-extractionbucket3/papers3/S45_p53 mu...
# 24  gs://tlab-extractionbucket3/papers3/S46_Charac...
# 25  gs://tlab-extractionbucket3/papers3/S47_CD103 ...
# 26  gs://tlab-extractionbucket3/papers3/S48_Progno...
# 27  gs://tlab-extractionbucket3/papers3/S49_L1CAM ...
# 28  gs://tlab-extractionbucket3/papers3/S50_Silenc...
# 29  gs://tlab-extractionbucket3/papers3/S51_DNA mi...
# 30  gs://tlab-extractionbucket3/papers3/S52_Expres...
# 31  gs://tlab-extractionbucket3/papers3/S53_ARID1A...
# 32  gs://tlab-extractionbucket3/papers3/S54_L1 cel...
# 33  gs://tlab-extractionbucket3/papers3/S55_Eviden...
# 34  gs://tlab-extractionbucket3/papers3/S56_PIK3CA...
# 35  gs://tlab-extractionbucket3/papers3/S57_Immuno...
# 36  gs://tlab-extractionbucket3/papers3/S58_The au...
# 37  gs://tlab-extractionbucket3/papers3/S59_Stathm...
# 38  gs://tlab-extractionbucket3/papers3/S60_IGF2BP...
# 39  gs://tlab-extractionbucket3/papers3/S61_EphA2 ...
# 40  gs://tlab-extractionbucket3/papers3/S62_Aromat...
# 41  gs://tlab-extractionbucket3/papers3/S63_Expres...
# 42  gs://tlab-extractionbucket3/papers3/S64_Ovaria...
# 43  gs://tlab-extractionbucket3/papers3/S65_Prosta...
# 44  gs://tlab-extractionbucket3/papers3/S66_GPR30-...
# 45  gs://tlab-extractionbucket3/papers3/S67_Activa...
# 46  gs://tlab-extractionbucket3/papers3/S68_HER-2 ...
# 47  gs://tlab-extractionbucket3/papers3/S69_Ezrin ...
# 48  gs://tlab-extractionbucket3/papers3/S70_Replic...
# 49  gs://tlab-extractionbucket3/papers3/S71_Intrat...
# 50  gs://tlab-extractionbucket3/papers3/S72_L1 exp...
#
#                             Primary location of study
# 1   {'value': 'Calgary, Canada', 'confidence': ['9...
# 2   {'value': 'Manchester, UK', 'confidence': ['90...
# 3   {'value': 'Vancouver, Canada', 'confidence': [...
# 4   {'value': 'n/a', 'confidence': ['0', 'The loca...
# 5   {'value': 'Lund, Sweden', 'confidence': ['95',...
# 6   {'value': 'Calgary, AB, Canada', 'confidence':...
# 7   {'value': 'Calgary, Alberta, Canada', 'confide...
# 8   {'value': 'Vancouver, Canada', 'confidence': [...
# 9   {'value': 'Vancouver, Canada', 'confidence': [...
# 10  {'value': 'Utrecht, The Netherlands', 'confide...
# 11  {'value': 'Houston, USA', 'confidence': ['90',...
# 12  {'value': 'Groningen, The Netherlands', 'confi...
# 13  {'value': 'Sapporo, Japan', 'confidence': ['10...
# 14  {'value': 'Taipei, Taiwan', 'confidence': ['10...
# 15  {'value': 'Athens, Greece', 'confidence': ['95...
# 16  {'value': 'Nagoya, Japan', 'confidence': ['100...
# 17  {'value': 'Vancouver, Canada', 'confidence': [...
# 18  {'value': 'Rochester, USA', 'confidence': ['10...
# 19  {'value': 'Bergen, Norway', 'confidence': ['95...
# 20  {'value': 'Los Angeles, California', 'confiden...
# 21  {'value': 'Sendai, Japan', 'confidence': ['100...
# 22  {'value': 'Cambridge, UK', 'confidence': ['90'...
# 23  {'value': 'Tokyo, Japan', 'confidence': ['100'...
# 24  {'value': 'Shanghai, China', 'confidence': ['9...
# 25  {'value': 'Groningen, The Netherlands', 'confi...
# 26  {'value': 'Leiden, The Netherlands', 'confiden...
# 27  {'value': 'Nijmegen, The Netherlands', 'confid...
# 28  {'value': 'Guangzhou, China', 'confidence': ['...
# 29  {'value': 'Tokorozawa, Japan', 'confidence': [...
# 30  {'value': 'Shenyang, China', 'confidence': ['9...
# 31  {'value': 'Toronto and Vancouver, Canada', 'co...
# 32  {'value': 'Leiden, The Netherlands', 'confiden...
# 33  {'value': 'Calgary, Canada', 'confidence': ['9...
# 34  {'value': 'Tsukuba, Japan', 'confidence': ['95...
# 35  {'value': 'Moedling/Vienna, Austria', 'confide...
# 36  {'value': 'British Columbia, Canada', 'confide...
# 37  {'value': 'Bergen, Norway', 'confidence': ['80...
# 38  {'value': 'Vancouver, Canada', 'confidence': [...
# 39  {'value': 'Houston, Texas', 'confidence': ['10...
# 40  {'value': 'Groningen, The Netherlands', 'confi...
# 41  {'value': 'Okayama, Japan', 'confidence': ['10...
# 42  {'value': 'Vancouver, British Columbia, Canada...
# 43  {'value': 'Buffalo, New York', 'confidence': [...
# 44  {'value': 'Albuquerque, NM, USA', 'confidence'...
# 45  {'value': 'Kanazawa, Japan', 'confidence': ['9...
# 46  {'value': 'Columbus, OH', 'confidence': ['100'...
# 47  {'value': 'Halle, Germany', 'confidence': ['10...
# 48  {'value': 'Hong Kong, China', 'confidence': ['...
# 49  {'value': 'Haifa, Israel', 'confidence': ['100...
# 50  {'value': 'Rehovot, Israel', 'confidence': ['9...
